# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# * single-turn: 한번하고 끝 (stateless)
# * multi-turn: 몇번의 정보를 저장해놓고 사용(stateful)
#  대부분 stateful 모델에서는 이전에 했던 내역들(대화 내용, 로그)를 요약해서 현재 프롬프트에 붙여서 입력으로 넣어줌

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# !pip install --quiet openai
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 328.5/328.5 kB 4.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 75.6/75.6 kB 5.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 77.9/77.9 kB 5.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.3/58.3 kB 5.7 MB/s eta 0:00:00

# %%
import os, openai
from google.colab import userdata

os.environ["OPENAI_API_KEY"]=userdata.get('op')
openai.api_key=os.getenv("OPENAI_API_KEY")

# %%
client=openai.OpenAI()

response=client.chat.completions.create(
    model='gpt-4o',
    messages=[
        {
            "role":'user',
            'content':[
                {
                    'type':'text',
                    'text':"이 피검사 결과를 상세하게 설명해줘, 그리고 문제가 된다면 어떻게 고쳐야하는지도 알려줘",
                },
                {
                    "type":"image_url",
                    "image_url":
                    {
                        "url":"https://emi.parkview.com/media/Image/Dashboard_835_lab-results_10_23.jpeg",
                    },
                },
            ],
        },
    ],
    max_tokens=800,
)

# %%
print(response.choices[0].message.content)
# Out:
# 이 피검사 결과는 주로 지질 프로파일과 관련된 항목들을 보여주고 있습니다. 각 항목과 함께 높음을 의미하는 "H" 표시가 있습니다. 각각의 항목과 그 의미를 설명하겠습니다.
#
# 1. **총 콜레스테롤 (Cholesterol): 299 mg/dL (H)**
#    - 일반적으로 총 콜레스테롤 수치는 200 mg/dL 미만이 정상으로 간주됩니다.
#    - 총 콜레스테롤 수치가 높은 것은 심혈관 질환의 위험을 증가시킬 수 있습니다.
#
# 2. **트리글리세리드 (Triglyceride): 250 mg/dL (H)**
#    - 정상적인 트리글리세리드 수치는 150 mg/dL 미만입니다.
#    - 트리글리세리드 수치가 높으면 심장 질환의 위험이 증가할 수 있습니다.
#
# 3. **HDL-콜레스테롤 (HDL-C): 62 mg/dL (H)**
#    - HDL 콜레스테롤은 "좋은" 콜레스테롤로 간주되며, 높은 수치는 일반적으로 좋은 것으로 간주됩니다.
#    - 일반적으로 남성은 40 mg/dL 이상, 여성은 50 mg/dL 이상의 수치가 권장됩니다. 수치가 60 mg/dL 이상일 경우 심장 질환의 위험이 낮을 수 있습니다.
#
# 4. **LDL-콜레스테롤 (LDL-C): 210 mg/dL (H)**
#    - 일반적으로 LDL 콜레스테롤 수치는 100 mg/dL 미만이 권장됩니다.
#    - LDL 콜레스테롤 수치가 높으면 동맥 경화증 및 심장 질환의 위험이 증가할 수 있습니다.
#
# 이 검사 결과는 전반적으로 콜레스테롤과 트리글리세리드 수치가 높아 심혈관 질환의 위험 증가와 관련이 있습니다. 이를 개선하기 위해 다음과 같은 조치를 취할 수 있습니다:
#
# 1. **식이 조절**:
#    - 포화 지방과 트랜스 지방 섭취를 줄이고, 오메가-3 지방산이 풍부한 음식을 섭취합니다. (예: 생선, 견과류)
#    - 섬유질이 풍부한 음식 섭취를 늘려줍니다. (예: 과일, 채소, 전곡류)
#
# 2. **운동**:
# ...

# %%
response=client.chat.completions.create(
    model='gpt-4o',
    messages=[
        {
            "role":'user',
            'content':[
                {
                    'type':'text',
                    'text':"이 피검사 결과를 상세하게 설명해줘, 하지만 재치있게 설명해줘.",
                },
                {
                    "type":"image_url",
                    "image_url":
                    {
                        "url":"https://emi.parkview.com/media/Image/Dashboard_835_lab-results_10_23.jpeg",
                    },
                },
            ],
        },
    ],
    max_tokens=800,
)

# %%
print(response.choices[0].message.content)
# Out:
# 물론! 이 피검사 결과를 아주 재치있게 설명해줄게.
#
# 자, 이 검사 결과는 마치 당신의 혈관에서 열린 카니발 같죠! 하나씩 살펴볼까요?
#
# 1. **Cholesterol (총 콜레스테롤):**
#    - 결과: 299 mg/dL (H)
#    - 해석: 오, 이건 마치 콜레스테롤이 파티에 초대받지 않은 기분이네요. 적정 수준보다 높아서 "H"가 붙었어요. 이 정도면 콜레스테롤이 고층 아파트를 몇 채 지을 만큼 높은 상태예요. 건강을 위해 조금 조절이 필요하겠네요!
#
# 2. **Triglyceride (트리글리세라이드):**
#    - 결과: 250 mg/dL (H)
#    - 해석: 트리글리세라이드가 이 파티에 힘차게 참가하고 있는 것 같아요. 높은 수치는 마치 친구 집에 갈 때 피자를 한 다발 가져가는 것과 같달까요. 조금 줄이는 게 현명할지도요!
#
# 3. **HDL-C (좋은 콜레스테롤):**
#    - 결과: 62 mg/dL (H)
#    - 해석: 축하해요, 좋은 콜레스테롤은 꽤 높군요! 이건 마치 파티에서 애플 파이와 건강 음식을 잔뜩 가져온 것과 같아요. 하지만 너무 많아도 건강 관리가 필요하죠.
#
# 4. **LDL-C (나쁜 콜레스테롤):**
#    - 결과: 210 mg/dL (H)
#    - 해석: 오, 나쁜 콜레스테롤도 그 카니발에 꽤 많이 왔네요. 이건 마치 집안에 들어와야 할 먼지가 너무 많아진 상황 같아요. 줄여주는 것이 좋겠어요.
#
# 결론적으로, 이 혈액 검사 결과는 마치 혈관 속에서 열린 환상적인 파티처럼 보이지만, 떠들썩한 친구들을 조금씩 집으로 돌려보내는 것이 좋겠네요! 건강한 식습관과 운동으로 파티를 조금 가라앉히는 게 어떨까요? 웃으며 건강 관리 잘 하시길!

# %% [markdown]
# 어쨌든 사진에는 개인정보가 포함되어있기 때문에 이를 어떻게 처리할지 생각해봐야함
# 규제라던가 법을 생각해서 서비스를 만들 생각은 필수임.
